# %%
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
from datetime import datetime
from pandas import to_datetime
from matplotlib import pyplot as plt
from prophet import Prophet
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
from prophet.plot import plot_cross_validation_metric
import seaborn as sns
from sklearn.model_selection import ParameterGrid

# %matplotlib inline
# %config InlineBackend.figure_format ='svg'
plt.style.use('ggplot')

# %% [markdown]
#             -------------------Data Visualization-------------------

# %%
#prepare the data
df = pd.read_csv('data/univariate/kenya/ken_brt_prophet.csv')
df['ds'] = pd.to_datetime(df['ds'])
df.tail(11)
# Out:
#            ds       y
# 39 1999-12-25  40.212
# 40 2000-12-25  40.037
# 41 2001-12-25  39.777
# 42 2002-12-25  39.468
# 43 2003-12-25  39.135
# 44 2004-12-25  38.773
# 45 2005-12-25  38.366
# 46 2006-12-25  37.890
# 47 2007-12-25  37.330
# 48 2008-12-25  36.678
# 49 2009-12-25  35.942

# %%
#visualize csv data
fig, ax = plt.subplots()
ax.plot(df['ds'],df['y'])

#transform the ticks (dates) ----- picked directly from matplotlib
# Major ticks every 6 months.
#fmt_year = mdates.MonthLocator(interval = 60)
#ax.xaxis.set_major_locator(fmt_year)

# Text in the x axis will be displayed in 'YYYY' format.
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotates and right aligns the x labels, and moves the bottom of the axes up to make room for them.
#fig.autofmt_xdate()
plt.xlabel('Year')
plt.ylabel('Birth Rate')
plt.title('Birth Rate crude(per 1000 people)')
plt.show()

# %% [markdown]
#                     -----Start Hyperparameter Tuning-----

# %%
param_grid = {  
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
    'n_changepoints' : [10,15,20],
    'seasonality_mode':('multiplicative','additive')
}

grid = ParameterGrid(param_grid)
cnt = 0
for p in grid:
    cnt = cnt+1

print('Total Possible Models',cnt)
# Out:
# Total Possible Models 96

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
training_data = df[df['ds']<'2010-12-25'].copy()
test_data = df[df['ds']>='2010-12-25'].copy().reset_index()
test_data
# Out:
#    index         ds       y
# 0     50 2010-12-25  35.128
# 1     51 2011-12-25  34.249
# 2     52 2012-12-25  33.333
# 3     53 2013-12-25  32.415
# 4     54 2014-12-25  31.522
# 5     55 2015-12-25  30.688
# 6     56 2016-12-25  29.943
# 7     57 2017-12-25  29.296
# 8     58 2018-12-25  28.748
# 9     59 2019-12-25  28.298

# %%
model_parameters = pd.DataFrame(columns = ['training_MAPE', 'test_MAPE','Parameters'])

for p in grid:
    test = pd.DataFrame()
    print(p)

    
    model =Prophet(changepoint_prior_scale = p['changepoint_prior_scale'],
                         seasonality_prior_scale = p['seasonality_prior_scale'],
                         seasonality_mode = p['seasonality_mode'],
                         n_changepoints = p['n_changepoints'],
                         weekly_seasonality = False,
                         yearly_seasonality = False,
                         daily_seasonality = False
                       )
    
    model.fit(training_data)
    
    #train_forecast = train_model.make_future_dataframe(periods=10, freq='Y')
    training_future = pd.DataFrame(training_data['ds'],columns =['ds'])
    training_forecast = model.predict(training_future)
    
    test_future = pd.DataFrame(test_data['ds'],columns =['ds'])
    test_forecast = model.predict(test_future)
    #test=train_forecast[['ds','yhat']]
    
    #calculate MAPE using the real dataset and predicted values (remove the 10 years)
    training_MAPE = mean_absolute_percentage_error(training_data['y'], training_forecast['yhat'])
    test_MAPE = mean_absolute_percentage_error(test_data['y'],test_forecast['yhat'])
    
    print('Training Mean Absolute Percentage Error(MAPE)-- {}'.format(training_MAPE))
    print('Test Mean Absolute Percentage Error(MAPE)-- {}'.format(test_MAPE))
    model_parameters = model_parameters.append({'training_MAPE':training_MAPE,
                                                'test_MAPE':test_MAPE,
                                                'Parameters':p},ignore_index=True)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# {'changepoint_prior_scale': 0.001, 'n_changepoints': 10, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01}
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Training Mean Absolute Percentage Error(MAPE)-- 2.728553774002552
# Test Mean Absolute Percentage Error(MAPE)-- 11.96225916085183
# {'changepoint_prior_scale': 0.001, 'n_changepoints': 10, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1}
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# ...

# %% [markdown]
# ### Get best paramateters

# %%
parameters = model_parameters.sort_values(by=['test_MAPE'])
parameters = parameters.reset_index(drop=True)
parameters.head()
# Out:
#    training_MAPE  test_MAPE                                         Parameters
# 0       0.159706   9.130985  {'changepoint_prior_scale': 0.5, 'n_changepoin...
# 1       0.160383   9.134008  {'changepoint_prior_scale': 0.1, 'n_changepoin...
# 2       0.159778   9.139041  {'changepoint_prior_scale': 0.5, 'n_changepoin...
# 3       0.160861   9.161645  {'changepoint_prior_scale': 0.1, 'n_changepoin...
# 4       0.159258   9.171026  {'changepoint_prior_scale': 0.5, 'n_changepoin...

# %%
best_params = parameters['Parameters'][0]

# %% [markdown]
# ### Performance plot

# %%
final_model = Prophet(
                      changepoint_prior_scale= best_params['changepoint_prior_scale'],
                      seasonality_prior_scale = best_params['seasonality_prior_scale'],
                      n_changepoints = best_params['n_changepoints'],
                      seasonality_mode = best_params['seasonality_mode'],
                      weekly_seasonality = False,
                      yearly_seasonality = False,
                      daily_seasonality = False
)
final_model.fit(training_data)

# %%
training_future = pd.DataFrame(training_data['ds'],columns =['ds'])
training_forecast = final_model.predict(training_future)
training_forecast['y'] = training_data['y']
cols = ['ds','y', 'yhat', 'yhat_lower','yhat_upper', 'trend', 'trend_lower', 'trend_upper']
training_forecast  = training_forecast[cols]
training_forecast
# Out:
#            ds       y       yhat  yhat_lower  yhat_upper      trend  \
# 0  1960-12-25  51.156  51.150023   50.981805   51.290147  51.150023
# 1  1961-12-25  51.068  51.063931   50.910286   51.210164  51.063931
# 2  1962-12-25  50.976  50.977838   50.835024   51.139844  50.977838
# 3  1963-12-25  50.887  50.891746   50.734325   51.034002  50.891746
# 4  1964-12-25  50.807  50.805417   50.653460   50.955091  50.805417
# 5  1965-12-25  50.748  50.757967   50.607378   50.907256  50.757967
# 6  1966-12-25  50.723  50.710517   50.561102   50.868192  50.710517
# 7  1967-12-25  50.731  50.746049   50.584191   50.904443  50.746049
# 8  1968-12-25  50.768  50.781679   50.629504   50.934539  50.781679
# 9  1969-12-25  50.825  50.828417   50.679073   50.980665  50.828417
# 10 1970-12-25  50.887  50.875155   50.727286   51.026248  50.875155
# 11 1971-12-25  50.938  50.921860   50.765293   51.073458  50.921860
# 12 1972-12-25  50.958  50.968694   50.813330   51.121249  50.968694
# ...

# %%
  
test_future = pd.DataFrame(test_data['ds'],columns =['ds'])
test_forecast = final_model.predict(test_future)
test_forecast['y'] = test_data['y']
test_forecast = test_forecast[cols]
test_forecast
# Out:
#           ds       y       yhat  yhat_lower  yhat_upper      trend  \
# 0 2010-12-25  35.128  36.015958   35.857496   36.174824  36.015958
# 1 2011-12-25  34.249  35.601933   35.378255   35.844923  35.601933
# 2 2012-12-25  33.333  35.186773   34.791769   35.541928  35.186773
# 3 2013-12-25  32.415  34.772747   34.171853   35.376663  34.772747
# 4 2014-12-25  31.522  34.358722   33.474628   35.225153  34.358722
# 5 2015-12-25  30.688  33.944696   32.746143   35.092894  33.944696
# 6 2016-12-25  29.943  33.529536   31.981445   35.081031  33.529536
# 7 2017-12-25  29.296  33.115510   31.199426   35.001741  33.115510
# 8 2018-12-25  28.748  32.701485   30.385010   35.011257  32.701485
# 9 2019-12-25  28.298  32.287459   29.607127   34.994893  32.287459
#
#    trend_lower  trend_upper
# 0    36.001921    36.044761
# 1    35.437088    35.755232
# 2    34.840396    35.536777
# 3    34.216134    35.347942
# 4    33.472567    35.203214
# 5    32.776897    35.053608
# ...

# %%
sns.set(rc={'figure.figsize':(8,6)})
plt.axvspan(xmin =datetime.strptime('2010-12-25', '%Y-%m-%d'),
            xmax =datetime.strptime('2019-12-25', '%Y-%m-%d'),
            color = 'grey',
            alpha = 0.25)
plt.scatter(df['ds'], df['y'], facecolors = 'none', edgecolors = 'blue')
plt.plot(training_forecast['ds'], training_forecast['yhat'], color = 'green', label = 'train_predictions')
plt.fill_between(training_forecast['ds'],training_forecast['yhat_lower'], training_forecast['yhat_upper'], color = 'green', alpha =0.25)

plt.plot(test_forecast['ds'], test_forecast['yhat'], color = 'red', label = 'test_predictions')
plt.fill_between(test_forecast['ds'],test_forecast['yhat_lower'], test_forecast['yhat_upper'], color = 'red', alpha =0.25)

plt.xlim([datetime.strptime('1960-12-25', '%Y-%m-%d'), datetime.strptime('2019-12-25', '%Y-%m-%d')])
plt.ylim([10,70])
plt.xlabel('Year', fontsize = 18, fontweight = 'bold', color ='black')
plt.ylabel('Birth Rate', fontsize = 18, fontweight = 'bold', color ='black')
plt.xticks(fontsize = 18, fontweight = 'bold')
plt.yticks(fontsize = 18, fontweight = 'bold')
plt.title('Birth Rate crude(per 1000 people)', fontsize = 18, fontweight = 'bold')
plt.legend(loc='lower left', fontsize = 12)
plt.show()

# %% [markdown]
# ### Final model predictions

# %%
final_model = Prophet(
                      changepoint_prior_scale= best_params['changepoint_prior_scale'],
                      seasonality_prior_scale = best_params['seasonality_prior_scale'],
                      n_changepoints = best_params['n_changepoints'],
                      seasonality_mode = best_params['seasonality_mode'],
                      weekly_seasonality = False,
                      yearly_seasonality = False,
                      daily_seasonality = False
)
final_model.fit(df)

# %%
future = list()
for i in range(2020, 2031):
    future.append(datetime.strptime(str(i)+'-12-25', '%Y-%m-%d'))
future = pd.DataFrame(dates,columns =['ds'])

forecast = final_model.predict(future)
forecast['y'] = df['y']
forecast  = forecast[cols]
forecast.tail(15)
# Out:
#            ds       y       yhat  yhat_lower  yhat_upper      trend  \
# 0  2020-12-25  51.156  27.007508   26.868637   27.154254  27.007508
# 1  2021-12-25  51.068  26.211701   26.012981   26.430993  26.211701
# 2  2022-12-25  50.976  25.415893   25.106525   25.798316  25.415893
# 3  2023-12-25  50.887  24.620086   24.131888   25.205818  24.620086
# 4  2024-12-25  50.807  23.822099   23.098450   24.620954  23.822099
# 5  2025-12-25  50.748  23.026291   22.035241   24.198855  23.026291
# 6  2026-12-25  50.723  22.230484   21.014581   23.681302  22.230484
# 7  2027-12-25  50.731  21.434677   19.864179   23.257908  21.434677
# 8  2028-12-25  50.768  20.636689   18.742603   22.732641  20.636689
# 9  2029-12-25  50.825  19.840882   17.515964   22.333240  19.840882
# 10 2030-12-25  50.887  19.045074   16.477959   22.020745  19.045074
#
#     trend_lower  trend_upper
# 0     26.989689    27.031406
# 1     26.083280    26.364916
# 2     25.132182    25.783717
# 3     24.128234    25.207001
# ...

# %%
sns.set(rc={'figure.figsize':(10,8)})
plt.axvspan(xmin =datetime.strptime('2020-12-25', '%Y-%m-%d'),
            xmax =datetime.strptime('2030-12-25', '%Y-%m-%d'),
            color = 'grey',
            alpha = 0.25)
plt.scatter(df['ds'], df['y'], facecolors = 'none', edgecolors = 'blue')

plt.plot(forecast['ds'], forecast['yhat'], color = 'red', label = 'forecasted birth rate')
plt.fill_between(forecast['ds'],forecast['yhat_lower'], forecast['yhat_upper'], color = 'red', alpha =0.25)

plt.xlim([datetime.strptime('1960-12-25', '%Y-%m-%d'), datetime.strptime('2030-12-25', '%Y-%m-%d')])
plt.ylim([10,70])
plt.xlabel('Year', fontsize = 18, fontweight = 'bold', color ='black')
plt.ylabel('Birth Rate', fontsize = 18, fontweight = 'bold', color ='black')
plt.xticks(fontsize = 18, fontweight = 'bold')
plt.yticks(fontsize = 18, fontweight = 'bold')
plt.title('Birth Rate crude(per 1000 people)', fontsize = 18, fontweight = 'bold')
plt.legend(loc='lower left', fontsize = 12)
plt.show()

# %%
tuned_future = final_model.make_future_dataframe(periods=10, freq='Y')
tuned_forecast = final_model.predict(tuned_future)
tuned_forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(10)
# Out:
#            ds       yhat  yhat_lower  yhat_upper
# 60 2019-12-31  25.938859   25.809845   26.051808
# 61 2020-12-31  24.742396   24.609681   24.882382
# 62 2021-12-31  24.154215   23.958991   24.352582
# 63 2022-12-31  23.579798   23.238151   23.898883
# 64 2023-12-31  22.940968   22.393542   23.494906
# 65 2024-12-31  21.817156   21.054045   22.562126
# 66 2025-12-31  21.246650   20.084460   22.357662
# 67 2026-12-31  20.610951   19.176279   22.023450
# 68 2027-12-31  19.980168   18.223620   21.738705
# 69 2028-12-31  18.876252   16.855825   20.947795

# %%
fig = final_model.plot_components(tuned_forecast)

# %%
#check model perfomance using cross validation
#not sure how this works with little data

#create a custom cutoff date
cutoffs = pd.to_datetime(['1980-12-21','1990-12-21','2000-12-21'])

df_cv = cross_validation(final_model, initial='7300 days', period='1800 days', horizon = '365 days')

df_p = performance_metrics(df_cv)

fig = plot_cross_validation_metric(df_cv, metric='mse')
# Out:
# INFO:prophet:Making 8 forecasts with cutoffs between 1984-06-26 00:00:00 and 2018-12-25 00:00:00
#   0%|          | 0/8 [00:00<?, ?it/s]
# INFO:prophet:n_changepoints greater than number of observations. Using 18.

# %%
#visualize
fig, ax = plt.subplots()
ax.plot(df['ds'],df['y'], color = 'blue', label = 'Real Birth Rate')
ax.plot(tuned_forecast['ds'],tuned_forecast['yhat'], color = 'red', label = 'Predicted Birth Rate')

# Major ticks every 6 months.
fmt_year = mdates.MonthLocator(interval = 60)
ax.xaxis.set_major_locator(fmt_year)

# Text in the x axis will be displayed in 'YYYY' format.
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotates and right aligns the x labels, and moves the bottom of the axes up to make room for them.
fig.autofmt_xdate()
plt.xlabel('Year')
plt.legend()
plt.ylabel('Birth Rate')
plt.title('Birth Rate crude(per 1000 people)')
plt.show()

# %%
# report performance
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse = sqrt(mean_squared_error(df['y'],tuned_forecast.loc[:59, 'yhat']))
print('RMSE: %.3f' %  rmse)
# Out:
# RMSE: 0.099

# %%
#visualize the test period (2000 to 2019)

#prep the data
df_a = df.loc[40:]
tuned_df_a = tuned_forecast.loc[40:59]


fig, ax = plt.subplots()
ax.plot(df_a['ds'],df_a['y'], color = 'blue', label = 'Real Birth Rate')
ax.plot(tuned_df_a['ds'],tuned_df_a['yhat'], color = 'red', label = 'Predicted Birth Rate')

# Major ticks every 6 months.
fmt_year = mdates.MonthLocator(interval = 60)
ax.xaxis.set_major_locator(fmt_year)

# Text in the x axis will be displayed in 'YYYY' format.
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotates and right aligns the x labels, and moves the bottom of the axes up to make room for them.
fig.autofmt_xdate()
plt.xlabel('Year')
plt.legend()
plt.ylabel('Birth Rate')
plt.title('Birth Rate crude(per 1000 people) (2000-2019)')
plt.show()
sns.set(rc={'figure.figsize':(8,6)})
